# %%
from pyspark.mllib.linalg import Vectors
from pyspark.mllib.feature import PCA
input = sc.textFile("wasb:///iris-multiclass.csv")
splitter = input.map(lambda line: line.split(','))
vec = splitter.map(lambda line: Vectors.dense(float(line[0]), float(line[1]), float(line[2]), float(line[3])))
vec.take(5)
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>2</td><td>application_1481411712782_0008</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://hn1-mysia.05ajb0c3rupuvg3di2sqgf1xuf.cx.internal.cloudapp.net:8088/proxy/application_1481411712782_0008/">Link</a></td><td><a target="_blank" href="http://10.0.0.5:30060/node/containerlogs/container_1481411712782_0008_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkContext available as 'sc'.
# HiveContext available as 'sqlContext'.
# [DenseVector([5.1, 3.5, 1.4, 0.2]), DenseVector([7.0, 3.2, 4.7, 1.4]), DenseVector([6.3, 3.3, 6.0, 2.5]), DenseVector([4.9, 3.0, 1.4, 0.2]), DenseVector([6.4, 3.2, 4.5, 1.5])]

# %%
model = PCA(2).fit(vec)

# %%
transformed = model.transform(vec)
transformed.take(5)
# Out:
# [DenseVector([-2.8271, -5.6413]), DenseVector([-6.7961, -6.0002]), DenseVector([-8.0431, -5.3029]), DenseVector([-2.796, -5.1452]), DenseVector([-6.4438, -5.6339])]
