# %%
input = sc.textFile("wasb:///iris-multiclass.csv")
input.count()
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>application_1481411712782_0006</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://hn1-mysia.05ajb0c3rupuvg3di2sqgf1xuf.cx.internal.cloudapp.net:8088/proxy/application_1481411712782_0006/">Link</a></td><td><a target="_blank" href="http://10.0.0.5:30060/node/containerlogs/container_1481411712782_0006_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkContext available as 'sc'.
# HiveContext available as 'sqlContext'.
# 150

# %%
input.first()
# Out:
# u'5.1,3.5,1.4,0.2,Iris-setosa'

# %%
splitter = input.map(lambda line: line.split(','))
num = splitter.map(lambda line: (line[4], 1)).reduceByKey(lambda a, b: a + b)
num.take(3)
# Out:
# [(u'Iris-virginica', 50), (u'Iris-setosa', 50), (u'Iris-versicolor', 50)]

# %%
from pyspark.sql.types import *
schemaString = "SepalLength SepalWidth PetalLength PetalWidth Species"
fields = [StructField(field_name, StringType(), True) for field_name in schemaString.split()]
schema = StructType(fields)
df = sqlContext.createDataFrame(splitter, schema)
df.groupBy("Species").count().show()
# Out:
# +---------------+-----+
# |        Species|count|
# +---------------+-----+
# |    Iris-setosa|   50|
# | Iris-virginica|   50|
# |Iris-versicolor|   50|
# +---------------+-----+

# %%
df.registerTempTable("iris")
sqlContext.sql("SELECT Species, COUNT(Species) FROM iris GROUP BY Species").show()
# Out:
# +---------------+---+
# |        Species|_c1|
# +---------------+---+
# |    Iris-setosa| 50|
# | Iris-virginica| 50|
# |Iris-versicolor| 50|
# +---------------+---+

# %%
from pyspark.sql.types import *
schemaString = "SepalLength SepalWidth PetalLength PetalWidth Species"
fields = [StructField(field_name, StringType(), True) for field_name in schemaString.split()]
schema = StructType(fields)
df = sqlContext.createDataFrame(splitter, schema)
df.groupBy("Species").count().show()
# Out:
# +---------------+-----+
# |        Species|count|
# +---------------+-----+
# |    Iris-setosa|   50|
# | Iris-virginica|   50|
# |Iris-versicolor|   50|
# +---------------+-----+

# %%
input = sc.textFile("wasb:///iris-multiclass.csv")
input.count()
# Out:
# 150

# %%
input.first()
# Out:
# u'5.1,3.5,1.4,0.2,Iris-setosa'

# %%
splitter = input.map(lambda line: line.split(','))
num = splitter.map(lambda line: (line[4], 1)).reduceByKey(lambda a, b: a + b)
num.take(3)
# Out:
# [(u'Iris-virginica', 50), (u'Iris-setosa', 50), (u'Iris-versicolor', 50)]

# %%
from pyspark.sql.types import *
schemaString = "SepalLength SepalWidth PetalLength PetalWidth Species"
fields = [StructField(field_name, StringType(), True) for field_name in schemaString.split()]
schema = StructType(fields)
df = sqlContext.createDataFrame(splitter, schema)
df.groupBy("Species").count().show()
# Out:
# +---------------+-----+
# |        Species|count|
# +---------------+-----+
# |    Iris-setosa|   50|
# | Iris-virginica|   50|
# |Iris-versicolor|   50|
# +---------------+-----+

# %%
df.registerTempTable("iris")
sqlContext.sql("SELECT Species, COUNT(Species) FROM iris GROUP BY Species").show()
# Out:
# +---------------+---+
# |        Species|_c1|
# +---------------+---+
# |    Iris-setosa| 50|
# | Iris-virginica| 50|
# |Iris-versicolor| 50|
# +---------------+---+
